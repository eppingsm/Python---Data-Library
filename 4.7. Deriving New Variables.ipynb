# %% [markdown]
# Deriving New Variables

# %%
# Import libraries
import pandas as pd 
import numpy as np
import os

# %%
#import data frame using the following code\\\\n\\\n",
df_seven = pd.read_pickle(r'C:\\\\\\\\Users\\\\\\\\eppin\\\\\\\\12-2020 Instacart Basket Analysis\\\\\\\\02 Data\\\\\\\\Original Data\\\\\\\\df_six.pkl')

# %%
df = df_seven[:1000000]

# %%
df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#    Unnamed: 0 product_name  aisle_id  department_id  prices _merge
# ...

# %%
df.shape
# Out:
# (1000000, 16)

# %% [markdown]
# #right a function just like and if/and statement in excel
# #removed this code from the working kernels so as to used the .loc function suggested by python
# def price_label(row):
#
#     if row['prices']<=5:
#         return 'Low range product'
#     elif (row['prices']>5) and (row['prices']<=15):
#         return 'Mid range product'
#     elif row['prices']>15:
#         return 'High'
#     else:
#         return 'Not enough data'

# %%
# df['price_range'] = df.apply(price_label, axis = 1)

# %%
# df['price_range'].value_counts(dropna = False)

# %%
df['prices'].max()
# Out:
# 14.8

# %%
#location function output - create one for each if statement in different kernels 
df_seven.loc[df_seven['prices']>15, 'price_range_loc'] = 'High range product'

# %%
#same as writing and IF - THEN statement in excel
df_seven.loc[(df_seven['prices']<=15) & (df['prices']>=5), 'price_range_loc'] = 'Mid range product'

# %%
df_seven.loc[df_seven['prices']<5, 'price_range_loc'] = 'Low range product'

# %%
#count the instances of each value in this data frame
df_seven['price_range_loc'].value_counts(dropna=False)
# Out:
# NaN                   21287709
# Low range product      9900417
# Mid range product       799055
# High range product      417678
# Name: price_range_loc, dtype: int64

# %%
#forloops
for x in range (30,44):
    print("my age is %d" % (x))
# Out:
# my age is 30
# my age is 31
# my age is 32
# my age is 33
# my age is 34
# my age is 35
# my age is 36
# my age is 37
# my age is 38
# my age is 39
# my age is 40
# my age is 41
# my age is 42
# my age is 43

# %%
df_seven.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#    Unnamed: 0 product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
#renaming a column using pandas
ords_prods_merged = df_seven.rename(columns={'order_dow': 'Order_Day_Of_Week'}, index={'ONE': 'Row_1'})

# %%
ords_prods_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  Order_Day_Of_Week  \
# 0   2539329        1    prior             1                  2
# 1   2398795        1    prior             2                  3
# 2    473747        1    prior             3                  3
# 3   2254736        1    prior             4                  4
# 4    431534        1    prior             5                  4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered  Unnamed: 0 product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
ords_prods_merged['Order_Day_Of_Week'].value_counts(dropna=False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: Order_Day_Of_Week, dtype: int64

# %%
#create an empty list
result = []

for value in ords_prods_merged["Order_Day_Of_Week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
#What is it that we are doing here? Am I creating a new column called busiest day?
ords_prods_merged['busiest_day']=result

# %%
ords_prods_merged['busiest_day'].value_counts(dropna=False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %% [markdown]
# For Busiest Days instead of Busiest Day the DataFrame will have name ords_prods_merged)_2

# %%
#check for two different statements in the IF and ELIF functions
result_2 = []

for value in ords_prods_merged["Order_Day_Of_Week"]:
  if value == 1 or value == 0:
    result_2.append('Busiest days')
  elif value == 4 or value == 3:
    result_2.append('Least busy days')
  else:
    result_2.append('Regularly busy')

# %%
result_2
# Out:
# ['Regularly busy',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Least busy days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy days',
#  'Regularly busy',
#  'Least busy days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Least busy days',
#  'Least busy days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
# ...

# %%
ords_prods_merged['busiest_days']=result_2

# %% [markdown]
# Notes on the changed code can be found in this segment
# busiest days - 11864412
# slowest days - 7624336

# %%
ords_prods_merged['busiest_days'].value_counts(dropna=False)
# Out:
# Regularly busy     12916111
# Busiest days       11864412
# Least busy days     7624336
# Name: busiest_days, dtype: int64

# %% [markdown]
# Busiest Hours of the Day

# %%
ords_prods_merged['order_hour_of_day'].value_counts(dropna=False)
#top 8 - 10,11,14,15,13,12,16,9
#bottom 8 - 3,4,2,5,1,0,6,23
#else - middle
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %%
#check for two different statements in the IF and ELIF functions
result_3 = []

for value in ords_prods_merged["order_hour_of_day"]:
  if value == 10 or value == 11 or value == 14 or value == 15 or value == 13 or value == 12 or value == 16 or value == 9:
    result_3.append('Busiest period')
  elif value == 4 or value == 3 or value == 2 or value == 5 or value == 1 or value == 0 or value == 6 or value == 23:
    result_3.append('Slowest period')
  else:
    result_3.append('Average busy')

# %%
ords_prods_merged['busiest_period']=result_3

# %% [markdown]
# Busiest Period Frequency Chart Below

# %%
ords_prods_merged['busiest_period'].value_counts(dropna=False)
# Out:
# Busiest period    21118071
# Average busy       9997651
# Slowest period     1289137
# Name: busiest_period, dtype: int64

# %%
#exporting the df to a pickle format
ords_prods_merged.to_pickle(r'C:\\\\\\\\Users\\\\\\\\eppin\\\\\\\\12-2020 Instacart Basket Analysis\\\\\\\\02 Data\\\\\\\\Original Data\\\\\\\\df_ords_prods_merged_7.pkl')
